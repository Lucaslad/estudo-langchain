# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA

import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = ChatNVIDIA(
  model="nvidia/nemotron-3-super-120b-a12b",
  api_key=os.getenv("NVIDIA_API_KEY"), 
)

print(llm.invoke("Teste").content)
# Out:
# Olá! Tudo bem? 😊 Só passando para confirmar que estou aqui e pronto para ajudar. Se tiver alguma pergunta ou precisar de algo, é só falar! Como posso auxiliá-lo hoje?
